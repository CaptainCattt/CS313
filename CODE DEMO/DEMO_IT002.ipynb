# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install anvil-uplink
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
import anvil.server

# %%
anvil.server.connect("server_QMQP7KRVUD4ETY2H57WHDG2J-SKU5P7FBQNTEFOKG")

# %%
def chuyen_doi_diem(diem):
    if diem >= 8:
        return 'A'
    elif diem >= 6.5:
        return 'B'
    elif diem >= 5:
        return 'C'
    else:
        return 'F'
def XL(df_fi):
  conditions = [(df_fi =="A"),
              (df_fi=="B"),
              (df_fi =="C"),
              (df_fi =="F")]
  choices = [0,1,2,3]
  df_fi_1 = np.select(conditions, choices, default='Unknown')
  return df_fi_1

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import joblib 
import pandas as pd
model = joblib.load("/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/CHẠY THỰC NGHIỆM/Random_Forest.joblib")
@anvil.server.callable
def Predict_IT002(IT001,IT003,IT004,IT005,IT007,MA005,MA004,MA003,MA006):
  IT001=chuyen_doi_diem(IT001)
  IT003=chuyen_doi_diem(IT003)
  IT004 = chuyen_doi_diem(IT004)
  IT005 = chuyen_doi_diem(IT005)
  IT007 = chuyen_doi_diem(IT007)
  MA005 = chuyen_doi_diem(MA005)
  MA004 =chuyen_doi_diem(MA004)
  MA003 = chuyen_doi_diem(MA003)
  MA006 = chuyen_doi_diem(MA006)
  IT001 = XL(IT001)
  IT003 = XL(IT003)
  IT004= XL(IT004)
  IT005= XL(IT005)
  IT007 = XL(IT007)
  MA003= XL(MA003)
  MA004 = XL(MA004)
  MA005 = XL(MA005)
  MA006 = XL(MA006)
  
  result = model.predict([[IT001,IT003,IT004,IT005,
                           IT007,MA003,MA004,MA005,MA006]])
  if result ==0:
    return "Bạn có khả năng bị trượt môn"
  return "Bạn có khả năng sẽ qua môn"

# %%
print(Predict_IT002(8,9,7,8,9,5.6,5.5,5.8,8))
# Out:
# Qua

# %%
i=[]
IT001 = 10
IT001=chuyen_doi_diem(IT001)
IT001 = pd.factorize(IT001)
print(IT001)
# Out:
# (array([0]), array(['A'], dtype=object))
