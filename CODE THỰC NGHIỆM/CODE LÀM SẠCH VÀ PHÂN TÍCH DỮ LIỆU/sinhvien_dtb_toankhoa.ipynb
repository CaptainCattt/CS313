# %%
import pandas as pd

# %%
df = pandas.read_excel('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/Education_dataset_V2/sinhvien_dtb_toankhoa.xlsx')

# %%
df
# Out:
#                                            mssv  dtb_toankhoa  dtb_tichluy  \
# 0      C410FEC4XPvAibaEXe/odi52as1TQ/z6UAtEIyTx          7.00         7.00
# 1      4555C74CXPvAibaEXe8UBGVVSBKSkjQKdKZAX7FE          6.34         6.34
# 2      6FB8C971XPvAibaEXe8zjuWfAVBr9Syz83phZPbU          2.31         0.00
# 3      7D7299A4XPvAibaEXe9hYalhCsDQbVspsqAf44vo          8.21         8.21
# 4      590263C4XPvAibaEXe9mDsFtgVHJ/lr5wIkYTfyo          8.32         8.32
# ...                                         ...           ...          ...
# 13965  23418DFBXPvAibaEXe8fkFoA0ROB11ZORpcgaZsN          3.33         0.00
# 13966  7CDE61ABXPvAibaEXe/VxWgTgtHe04Encl5UmaMi          8.59         8.59
# 13967  658FB4D5XPvAibaEXe/VxWgTgtHe02gf1ImYGwpE          8.50         8.50
# 13968  7114E632XPvAibaEXe/VxWgTgtHe08jgqfqtydmc          5.16         6.32
# 13969  F3DA4B4EXPvAibaEXe/jswsdDHMZJUhPMDC53M8G          0.00         0.00
#
#        sotc_tichluy
# 0             144.0
# 1             153.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13970 entries, 0 to 13969
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mssv          13970 non-null  object
#  1   dtb_toankhoa  13648 non-null  float64
#  2   dtb_tichluy   13648 non-null  float64
#  3   sotc_tichluy  13648 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 436.7+ KB

# %%
df_Khuvuc = pd.read_excel('/content/thpr (version 1).xlsx',sheet_name =  'Table 2')

# %%
df_Khuvuc
# Out:
#       STT  Ma Tinh    Tên Tỉnh/TP  Mã  Quận/Huyện             Tên Quận/Huyện   \
# 0        0       0             NaN             NaN                        NaN
# 1       1      01          Hà Nội              00     Sở Giáo dục và Đào tạo
# 2       2      01          Hà Nội              00     Sở Giáo dục và Đào tạo
# 3       3      01          Hà Nội              01               Quận Ba Đình
# 4       4      01          Hà Nội              01               Quận Ba Đình
# ...    ...     ...             ...             ...                        ...
# 4887  5337      64       Hậu Giang               9          Thành phố Ngã Bảy
# 4888  5338      64       Hậu Giang               9          Thành phố Ngã Bảy
# 4889  5339      64       Hậu Giang               9          Thành phố Ngã Bảy
# 4890  5340      65  Cục nhà trường               1    Cục Nhà trường - Hà Nội
# 4891  5341      65  Cục nhà trường               2  Cục Nhà trường - Đồng Nai
#
# ...

# %%
df_Khuvuc.head(10)
# Out:
#   STT  Ma Tinh Tên Tỉnh/TP  Mã  Quận/Huyện           Tên Quận/Huyện   \
# 0    0       0          NaN             NaN                      NaN
# 1   1      01       Hà Nội              00   Sở Giáo dục và Đào tạo
# 2   2      01       Hà Nội              00   Sở Giáo dục và Đào tạo
# 3   3      01       Hà Nội              01             Quận Ba Đình
# 4   4      01       Hà Nội              01             Quận Ba Đình
# 5   5      01       Hà Nội              01             Quận Ba Đình
# 6   6      01       Hà Nội              01             Quận Ba Đình
# 7   7      01       Hà Nội              01             Quận Ba Đình
# 8   8      01       Hà Nội              01             Quận Ba Đình
# 9   9      01       Hà Nội              01             Quận Ba Đình
#
#   MÃ TRƯỜNG                                   TEN_TRUONG  \
# 0         0                                          NaN
# 1      800                             Học ở nước ngoài
# ...

# %%
df_Khuvuc.dropna(subset = df_Khuvuc.columns[1],inplace = True)

# %%
df_Khuvuc.columns = df_Khuvuc.columns.str.strip()

# %%
df_Khuvuc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4884 entries, 0 to 4891
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   STT             4884 non-null   object
#  1   Ma Tinh         4884 non-null   object
#  2   Tên Tỉnh/TP     4883 non-null   object
#  3   Mã  Quận/Huyện  4883 non-null   object
#  4   Tên Quận/Huyện  4883 non-null   object
#  5   MÃ TRƯỜNG       4884 non-null   object
#  6   TEN_TRUONG      4873 non-null   object
#  7   Địa Chỉ         4760 non-null   object
#  8   KHU_VUC         4835 non-null   object
#  9   Trường  DTNT    4882 non-null   object
# dtypes: object(10)
# memory usage: 419.7+ KB

# %%
df_Khuvuc[df_Khuvuc.columns[1]].isna().sum()
# Out:
# 0

# %%
tinh = df_Khuvuc[df_Khuvuc.columns[1]].astype(int)

# %%
truong = df_Khuvuc[df_Khuvuc.columns[5]].astype(int)

# %%
df_tinh = pd.DataFrame({'lop12_matinh':tinh,'lop12_matruong':truong,'khuvuc':df_Khuvuc[df_Khuvuc.columns[8]]})

# %%
df_tinh
# Out:
#       lop12_matinh  lop12_matruong      khuvuc
# 0                0               0         NaN
# 1                1             800  Khu vực 3
# 2                1             900  Khu vực 3
# 3                1              62  Khu vực 3
# 4                1              66  Khu vực 3
# ...            ...             ...         ...
# 4887            64             411   Khu vực 1
# 4888            64             435   Khu vực 1
# 4889            64             440   Khu vực 1
# 4890            65               1   Khu vực 3
# 4891            65               2   Khu vực 2
#
# [4884 rows x 3 columns]

# %%
df_tinh.to_csv('/content/tinh.csv')
