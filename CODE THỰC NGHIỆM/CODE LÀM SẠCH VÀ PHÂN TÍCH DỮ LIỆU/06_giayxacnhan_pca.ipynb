# %%
import pandas as pd
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/Education_dataset_V2/06.giayxacnhan.xlsx')

# %%
df1= pd.read_csv('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/final_edu_data/06_giayxacnhan.csv')

# %%
df.columns = df.columns.str.strip()

# %%
df1
# Out:
#        giayxacnhan_id  maloaigiay           ngaysubmit  \
# 0                 517           2  2013-05-19 23:56:36
# 1                 518           2  2013-05-19 23:57:17
# 2                 649           2  2013-08-26 07:36:53
# 3                 669           2  2013-09-03 11:14:48
# 4                 676           2  2013-09-04 10:35:23
# ...               ...         ...                  ...
# 27187           43994           1  2021-06-10 20:45:46
# 27188           43995           1  2021-06-10 21:27:44
# 27189           43997           1  2021-06-11 09:13:29
# 27190           44000           1  2021-06-11 13:47:49
# 27191           44002           1  2021-06-12 15:51:15
#
#                                            masv  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd
# 3      D0FE4969XPvAibaEXe/yXiKgsgy0slCmJ5EKt6Ki
# 4      71ABA6D5XPvAibaEXe9fwZBwsCOuQNwK1At3AEjT
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27192 entries, 0 to 27191
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   giayxacnhan_id  27192 non-null  int64
#  1   maloaigiay      27192 non-null  int64
#  2   ngaysubmit      27192 non-null  object
#  3   masv            27192 non-null  object
#  4   lydoxacnhan     27192 non-null  object
#  5   dain            27082 non-null  float64
#  6   baosai          27145 non-null  float64
#  7   lydocapthe      27164 non-null  object
#  8   lydosai         27164 non-null  object
#  9   daky            26664 non-null  float64
#  10  dadongdau       27118 non-null  float64
#  11  daphat          27155 non-null  float64
#  12  trangthai       27157 non-null  float64
#  13  ngayphat        27160 non-null  object
#  14  hocky           27192 non-null  int64
#  15  nam             27192 non-null  int64
# dtypes: float64(6), int64(4), object(6)
# ...

# %%
df
# Out:
#        giayxacnhan_id  maloaigiay          ngaysubmit  \
# 0               517.0         2.0 2013-05-19 23:56:36
# 1               518.0         2.0 2013-05-19 23:57:17
# 2               649.0         2.0 2013-08-26 07:36:53
# 3               669.0         2.0 2013-09-03 11:14:48
# 4               676.0         2.0 2013-09-04 10:35:23
# ...               ...         ...                 ...
# 27254             NaN         1.0                 NaT
# 27255             NaN         1.0                 NaT
# 27256             NaN         1.0                 NaT
# 27257             NaN         1.0                 NaT
# 27258             NaN         1.0                 NaT
#
#                                            mssv                   lydoxacnhan  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd
# 3      D0FE4969XPvAibaEXe/yXiKgsgy0slCmJ5EKt6Ki
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27259 entries, 0 to 27258
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   giayxacnhan_id  19919 non-null  float64
#  1   maloaigiay      27192 non-null  float64
#  2   ngaysubmit      1429 non-null   datetime64[ns]
#  3   mssv            27192 non-null  object
#  4   lydoxacnhan     27192 non-null  object
#  5   dain            27100 non-null  float64
#  6   baosai          27166 non-null  float64
#  7   lydocapthe      27192 non-null  object
#  8   hocky           27192 non-null  object
#  9   namhoc          3895 non-null   float64
#  10  lydosai         27192 non-null  object
#  11  daky            27192 non-null  object
#  12  dadongdau       27192 non-null  object
#  13  daphat          27179 non-null  float64
#  14  trangthai       27192 non-null  object
#  15  ngayphat        27188 non-null  object
# ...

# %%
df.dropna(subset=['giayxacnhan_id'],inplace = True)

# %%
df_1.dropna(subset=['giayxacnhan_id'],inplace = True)

# %%
df.reset_index()
# Out:
#        index  giayxacnhan_id  maloaigiay          ngaysubmit  \
# 0          0           517.0         2.0 2013-05-19 23:56:36
# 1          1           518.0         2.0 2013-05-19 23:57:17
# 2          2           649.0         2.0 2013-08-26 07:36:53
# 3          3           669.0         2.0 2013-09-03 11:14:48
# 4          4           676.0         2.0 2013-09-04 10:35:23
# ...      ...             ...         ...                 ...
# 19914  19963         34981.0         1.0                 NaT
# 19915  19964         34982.0         1.0                 NaT
# 19916  19965         34983.0         1.0                 NaT
# 19917  19966         34984.0         1.0                 NaT
# 19918  19967         34985.0         5.0                 NaT
#
#                                            mssv                   lydoxacnhan  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd
# ...

# %%
df1.reset_index()
# Out:
#        index  giayxacnhan_id  maloaigiay           ngaysubmit  \
# 0          0             517           2  2013-05-19 23:56:36
# 1          1             518           2  2013-05-19 23:57:17
# 2          2             649           2  2013-08-26 07:36:53
# 3          3             669           2  2013-09-03 11:14:48
# 4          4             676           2  2013-09-04 10:35:23
# ...      ...             ...         ...                  ...
# 27187  27187           43994           1  2021-06-10 20:45:46
# 27188  27188           43995           1  2021-06-10 21:27:44
# 27189  27189           43997           1  2021-06-11 09:13:29
# 27190  27190           44000           1  2021-06-11 13:47:49
# 27191  27191           44002           1  2021-06-12 15:51:15
#
#                                            masv  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd
# ...

# %%
df =  df.iloc[:,0:16]

# %%
df
# Out:
#        giayxacnhan_id  maloaigiay          ngaysubmit  \
# 0               517.0         2.0 2013-05-19 23:56:36
# 1               518.0         2.0 2013-05-19 23:57:17
# 2               649.0         2.0 2013-08-26 07:36:53
# 3               669.0         2.0 2013-09-03 11:14:48
# 4               676.0         2.0 2013-09-04 10:35:23
# ...               ...         ...                 ...
# 19963         34981.0         1.0                 NaT
# 19964         34982.0         1.0                 NaT
# 19965         34983.0         1.0                 NaT
# 19966         34984.0         1.0                 NaT
# 19967         34985.0         5.0                 NaT
#
#                                            mssv                   lydoxacnhan  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd
# 3      D0FE4969XPvAibaEXe/yXiKgsgy0slCmJ5EKt6Ki
# ...

# %%
df1=df1.drop(columns=['lydocapthe','lydoxacnhan','lydosai','daky'])

# %%
df1
# Out:
#        giayxacnhan_id  maloaigiay           ngaysubmit  \
# 0                 517           2  2013-05-19 23:56:36
# 1                 518           2  2013-05-19 23:57:17
# 2                 649           2  2013-08-26 07:36:53
# 3                 669           2  2013-09-03 11:14:48
# 4                 676           2  2013-09-04 10:35:23
# ...               ...         ...                  ...
# 27187           43994           1  2021-06-10 20:45:46
# 27188           43995           1  2021-06-10 21:27:44
# 27189           43997           1  2021-06-11 09:13:29
# 27190           44000           1  2021-06-11 13:47:49
# 27191           44002           1  2021-06-12 15:51:15
#
#                                            masv  dain  baosai  dadongdau  \
# 0      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8   1.0     0.0        1.0
# 1      31D5D488XPvAibaEXe85Kg8gbEhwbxD0x3mi2el8   1.0     1.0        0.0
# 2      4DD248D9XPvAibaEXe+6MN9FoW2mqeloV0TjpGtd   1.0     1.0        0.0
# ...

# %%
df_str = pd.DataFrame({'giayxacnhan_id':df['giayxacnhan_id'],'lydocapthe':df['lydocapthe'],'lydoxacnhan':df['lydoxacnhan'],'lydosai':df['lydosai'],'daky':df['daky']})

# %%
df_mer= df_str.merge(df1,how='left' ,on = 'giayxacnhan_id')

# %%
df_mer
# Out:
#        giayxacnhan_id                  lydocapthe  \
# 0               517.0   Em làm mất thẻ sinh viên.
# 1               518.0    Em làm mất thẻ sinh viên
# 2               649.0                     Mất thẻ
# 3               669.0     bị móc bóp trên xe buýt
# 4               676.0           Mất thẻ sinh viên
# ...               ...                         ...
# 19914         34981.0                        NULL
# 19915         34982.0                        NULL
# 19916         34983.0                        NULL
# 19917         34984.0                        NULL
# 19918         34985.0                        NULL
#
#                         lydoxacnhan                             lydosai  \
# 0
# 1                                                                 trùng
# 2                                     Lên P.CTSV gặp a Hiển làm lại thẻ
# 3                                                Đến P.CTSV đăng ký thẻ
# ...

# %%
df_mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19919 entries, 0 to 19918
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   giayxacnhan_id  19919 non-null  float64
#  1   lydocapthe      19919 non-null  object
#  2   lydoxacnhan     19919 non-null  object
#  3   lydosai         19919 non-null  object
#  4   daky            19919 non-null  object
#  5   maloaigiay      19919 non-null  int64
#  6   ngaysubmit      19919 non-null  object
#  7   masv            19919 non-null  object
#  8   dain            19832 non-null  float64
#  9   baosai          19882 non-null  float64
#  10  dadongdau       19855 non-null  float64
#  11  daphat          19891 non-null  float64
#  12  trangthai       19891 non-null  float64
#  13  ngayphat        19891 non-null  object
#  14  hocky           19919 non-null  int64
#  15  nam             19919 non-null  int64
# dtypes: float64(6), int64(3), object(7)
# ...

# %%
df_mer.head(20)
# Out:
#     giayxacnhan_id                                         lydocapthe  \
# 0            517.0                          Em làm mất thẻ sinh viên.
# 1            518.0                           Em làm mất thẻ sinh viên
# 2            649.0                                            Mất thẻ
# 3            669.0                            bị móc bóp trên xe buýt
# 4            676.0                                  Mất thẻ sinh viên
# 5            702.0                           Em làm mất thẻ sinh viên
# 6            718.0              Thay đổi từ BM KH&KTTT sang Khoa KHMT
# 7            729.0                 Đi xe bus bị rơi mất thẻ sinh viên
# 8            734.0                                       đánh mất thẻ
# 9            736.0                                        Làm mất thẻ
# 10           748.0                                             bị mất
# 11           750.0                               Đi xe bus bị mất thẻ
# ...

# %%
df_mer.tail(20)
# Out:
#        giayxacnhan_id lydocapthe                   lydoxacnhan lydosai daky  \
# 19899         34966.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19900         34967.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19901         34968.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19902         34969.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19903         34970.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19904         34971.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19905         34972.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19906         34973.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19907         34974.0       NULL    'Đăng ký tạm trú tạm vắng'    NULL    0
# 19908         34975.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# 19909         34976.0       NULL   'Tạm hoãn nghĩa vụ quân sự'    NULL    0
# ...

# %%
df_mer.sample(20)
# Out:
#        giayxacnhan_id lydocapthe  \
# 14521         29188.0       NULL
# 18499         33461.0       NULL
# 10896         25125.0       NULL
# 4163          16552.0       NULL
# 5924          18840.0       NULL
# 201            4685.0
# 13353         27895.0       NULL
# 4808          17349.0       NULL
# 13576         28157.0       NULL
# 11092         25330.0       NULL
# 9461          23406.0       NULL
# 11071         25309.0       NULL
# 6284          19413.0       NULL
# 13316         27853.0       NULL
# 6460          19699.0       NULL
# 17789         32705.0       NULL
# 8645          22352.0       NULL
# 19554         34586.0       NULL
# 14018         28634.0       NULL
# 7218          20756.0       NULL
#
#                                              lydoxacnhan  \
# 14521                          'Xin gia hạn ở Ký túc xá'
# 18499                        'Tạm hoãn nghĩa vụ quân sự'
# 10896                                               NULL
# ...

# %%
# for i in df.columns:
df_mer = df_mer.replace(str("'"),str('')).replace(str('NULL'),str(''))
df_mer = df_mer.replace(str('NULL)'),str('')).replace(str('"'),str("")).replace(str('NULL);'),str(''))

# %%
df_mer
# Out:
#        giayxacnhan_id                  lydocapthe  \
# 0               517.0   Em làm mất thẻ sinh viên.
# 1               518.0    Em làm mất thẻ sinh viên
# 2               649.0                     Mất thẻ
# 3               669.0     bị móc bóp trên xe buýt
# 4               676.0           Mất thẻ sinh viên
# ...               ...                         ...
# 19914         34981.0                        NULL
# 19915         34982.0                        NULL
# 19916         34983.0                        NULL
# 19917         34984.0                        NULL
# 19918         34985.0                        NULL
#
#                         lydoxacnhan                             lydosai  \
# 0
# 1                                                                 trùng
# 2                                     Lên P.CTSV gặp a Hiển làm lại thẻ
# 3                                                Đến P.CTSV đăng ký thẻ
# ...

# %%
a ={0,4,5,8,9,10,11,12,14,15}
for i in a:
  try:
    df_mer[df_mer.columns[i]] =df_mer[df_mer.columns[i]].astype('int64')
  except:
    df_mer[df_mer.columns[i]] = pd.to_numeric(df_mer[df_mer.columns[i]], errors='coerce').astype('int64',errors='ignore')

# %%
df_mer[df_mer.columns[0]] =df_mer[df_mer.columns[0]].astype('int64')

# %%
df_mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19919 entries, 0 to 19918
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   giayxacnhan_id  19919 non-null  int64
#  1   lydocapthe      19919 non-null  object
#  2   lydoxacnhan     19919 non-null  object
#  3   lydosai         19919 non-null  object
#  4   daky            19439 non-null  float64
#  5   maloaigiay      19919 non-null  int64
#  6   ngaysubmit      19919 non-null  object
#  7   masv            19919 non-null  object
#  8   dain            19832 non-null  float64
#  9   baosai          19882 non-null  float64
#  10  dadongdau       19855 non-null  float64
#  11  daphat          19891 non-null  float64
#  12  trangthai       19891 non-null  float64
#  13  ngayphat        19891 non-null  object
#  14  hocky           19919 non-null  int64
#  15  nam             19919 non-null  int64
# dtypes: float64(6), int64(4), object(6)
# ...

# %%
df_mer.shape
# Out:
# (19919, 16)

# %%
df_mer.to_csv('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/edu_data_v2/06_giayxacnhan.csv',index=False)

# %% [markdown]
# ##Phân tích dữ liệu.

# %%
df= pd.read_csv('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/edu_data_v2/06_giayxacnhan.csv')

# %%
df
# Out:
#        giayxacnhan_id                  lydocapthe  \
# 0                 517   Em làm mất thẻ sinh viên.
# 1                 518    Em làm mất thẻ sinh viên
# 2                 649                     Mất thẻ
# 3                 669     bị móc bóp trên xe buýt
# 4                 676           Mất thẻ sinh viên
# ...               ...                         ...
# 19914           34981                        NULL
# 19915           34982                        NULL
# 19916           34983                        NULL
# 19917           34984                        NULL
# 19918           34985                        NULL
#
#                         lydoxacnhan                             lydosai  daky  \
# 0                                                                         1.0
# 1                                                                 trùng   0.0
# 2                                     Lên P.CTSV gặp a Hiển làm lại thẻ   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19919 entries, 0 to 19918
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   giayxacnhan_id  19919 non-null  int64
#  1   lydocapthe      19919 non-null  object
#  2   lydoxacnhan     19919 non-null  object
#  3   lydosai         19919 non-null  object
#  4   daky            19439 non-null  float64
#  5   maloaigiay      19919 non-null  int64
#  6   ngaysubmit      19919 non-null  object
#  7   masv            19919 non-null  object
#  8   dain            19832 non-null  float64
#  9   baosai          19882 non-null  float64
#  10  dadongdau       19855 non-null  float64
#  11  daphat          19891 non-null  float64
#  12  trangthai       19891 non-null  float64
#  13  ngayphat        19891 non-null  object
#  14  hocky           19919 non-null  int64
#  15  nam             19919 non-null  int64
# dtypes: float64(6), int64(4), object(6)
# ...

# %%
df.drop(df[df.columns[[0]]],axis = 1)
# Out:
#                        lydocapthe                   lydoxacnhan  \
# 0       Em làm mất thẻ sinh viên.
# 1        Em làm mất thẻ sinh viên
# 2                         Mất thẻ
# 3         bị móc bóp trên xe buýt
# 4               Mất thẻ sinh viên
# ...                           ...                           ...
# 19914                        NULL   'Tạm hoãn nghĩa vụ quân sự'
# 19915                        NULL   'Tạm hoãn nghĩa vụ quân sự'
# 19916                        NULL   'Tạm hoãn nghĩa vụ quân sự'
# 19917                        NULL   'Tạm hoãn nghĩa vụ quân sự'
# 19918                        NULL                          NULL
#
#                                   lydosai  daky  maloaigiay  \
# 0                                           1.0           2
# 1                                   trùng   0.0           2
# 2       Lên P.CTSV gặp a Hiển làm lại thẻ   0.0           2
# 3                  Đến P.CTSV đăng ký thẻ   NaN           2
# ...

# %%
len(df['lydoxacnhan'].unique())
# Out:
# 1460

# %%
df['lydosai'].unique()
# Out:
# array([' ', ' trùng', ' Lên P.CTSV gặp a Hiển làm lại thẻ',
#        ' Đến P.CTSV đăng ký thẻ', ' Liên hệ trực tiếp P.CTSV',
#        ' Liên hệ trực tiếp P.CTSV để làm lại thẻ',
#        ' Liên hệ trực tiếp phòng CTSV để bổ sung thông tin',
#        ' Đăng ký làm lại thẻ tại phòng CTSV',
#        ' Em liên hệ trực tiếp P.CTSV đăng ký làm lại thẻ',
#        ' Em liên hệ trực tiếp Phòng CTSBV để đăng ký làm lại thẻ',
#        ' Em liên hệ P.CTSV đăng ký làm lại thẻ',
#        ' Em liên hệ trực tiếp P.CTSV',
#        ' Liên hệ P.KHTC đóng lệ phí làm lại thẻ. ',
#        ' Em làm lại mẫu Giấy xác nhận sinh viên nha!',
#        ' Em liên hệ P. Kế hoạch tài chính để đóng tiền',
#        ' Em liên hệ P. Tài chính đóng tiền',
#        ' Em liên hệ P. Tài chính để đóng tiền',
#        ' Em liên hệ P. Tài chính đống tiền',
#        ' Em liên hệ Phòng KHTC đóng lệ phí làm lại thẻ',
#        ' Liên hệ trực tiếp Phòng CTSV xin làm lại thẻ',
# ...

# %%
df['maloaigiay'].value_counts()
# Out:
# 1    15463
# 3     3600
# 5      477
# 6      173
# 4      126
# 2       80
# Name: maloaigiay, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['maloaigiay'].value_counts().plot(kind='bar')
plt.title('Số lượng đơn đăng kí mỗi loại giấy xác nhận')
plt.xlabel('Loại giấy xác nhận')
plt.ylabel('Số đơn đăng kí')
plt.show()
