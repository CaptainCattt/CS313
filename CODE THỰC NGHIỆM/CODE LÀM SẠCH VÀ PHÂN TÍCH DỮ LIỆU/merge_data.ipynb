# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %%
df_sinhvien = pd.read_excel('/content/drive/MyDrive/MyComputer/Learning/Khai thác dữ liệu và ứng dụng - CS313.N21/Education_dataset_V2/01.sinhvien.xlsx', sheet_name='01 sinhvien')
df_sinhvien
# Out:
#            id                                      mssv   namsinh   gioitinh  \
# 0         1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0        1.0
# 1         2.0  2420ED57XPvAibaEXe/Lh6v1XxTKJa6JLFRUPkLM    1995.0        1.0
# 2         3.0  83B76C01XPvAibaEXe/lOccskaOiO2K46r7t4qnt    1994.0        1.0
# 3         4.0  91F785ABXPvAibaEXe/lOccskaOiO5y4GbVvuRQu    1995.0        1.0
# 4         5.0  007C275DXPvAibaEXe+TFgEDwYNnveOOmOYeYzF6    1995.0        1.0
# ...       ...                                       ...       ...        ...
# 8311  19283.0  7D7633B0XPvAibaEXe95IhrkYSGfcCQVGm4nFGyt    2000.0        1.0
# 8312  19284.0  AB431338XPvAibaEXe8xMCTZ03/BexWzDCyWVsT3    2001.0        1.0
# 8313  19285.0  75AD7B4AXPvAibaEXe8xMCTZ03/BewoGrWSt0ZXM    2001.0        1.0
# 8314  19345.0  CB263C18XPvAibaEXe8xMCTZ03/Be8yk40QWdPiR    2000.0        1.0
# 8315  21059.0  7CD9B404XPvAibaEXe8M4ltS8XjC9c/g97NvpP52    2001.0        1.0
#
# ...

# %%
df_sinhvien = df_sinhvien.iloc[:, :12]
print(df_sinhvien)
# Out:
#            id                                      mssv   namsinh   gioitinh  \
# 0         1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0        1.0
# 1         2.0  2420ED57XPvAibaEXe/Lh6v1XxTKJa6JLFRUPkLM    1995.0        1.0
# 2         3.0  83B76C01XPvAibaEXe/lOccskaOiO2K46r7t4qnt    1994.0        1.0
# 3         4.0  91F785ABXPvAibaEXe/lOccskaOiO5y4GbVvuRQu    1995.0        1.0
# 4         5.0  007C275DXPvAibaEXe+TFgEDwYNnveOOmOYeYzF6    1995.0        1.0
# ...       ...                                       ...       ...        ...
# 8311  19283.0  7D7633B0XPvAibaEXe95IhrkYSGfcCQVGm4nFGyt    2000.0        1.0
# 8312  19284.0  AB431338XPvAibaEXe8xMCTZ03/BexWzDCyWVsT3    2001.0        1.0
# 8313  19285.0  75AD7B4AXPvAibaEXe8xMCTZ03/BewoGrWSt0ZXM    2001.0        1.0
# 8314  19345.0  CB263C18XPvAibaEXe8xMCTZ03/Be8yk40QWdPiR    2000.0        1.0
# 8315  21059.0  7CD9B404XPvAibaEXe8M4ltS8XjC9c/g97NvpP52    2001.0        1.0
#
# ...

# %%
df_sinhvien.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8316 entries, 0 to 8315
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              8295 non-null   float64
#  1   mssv            8295 non-null   object
#  2    namsinh        8294 non-null   float64
#  3    gioitinh       8295 non-null   float64
#  4    noisinh        8295 non-null   object
#  5    lopsh          8295 non-null   object
#  6    khoa           8295 non-null   object
#  7    hedt           8295 non-null   object
#  8    khoahoc        8295 non-null   float64
#  9    chuyennganh2   8295 non-null   object
#  10   tinhtrang      8295 non-null   float64
#  11   diachi_tinhtp  8295 non-null   object
#  12  Column1         1549 non-null   object
#  13  _1              1040 non-null   object
#  14  _2              669 non-null    object
#  15  _3              406 non-null    object
#  16  _4              233 non-null    object
# ...

# %%
df_diem = pd.read_excel('/content/drive/MyDrive/MyComputer/Learning/Khai thác dữ liệu và ứng dụng - CS313.N21/Education_dataset_V2/02.diem.xlsx', sheet_name='02 diem')
df_diem

# %%
df_diem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99099 entries, 0 to 99098
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          20000 non-null  float64
#  1   mssv        98963 non-null  object
#  2    mamh       98963 non-null  object
#  3    malop      98963 non-null  object
#  4    sotc       98963 non-null  float64
#  5    namhoc     98963 non-null  float64
#  6    hocky      98963 non-null  float64
#  7    diem       98928 non-null  float64
#  8    trangthai  98963 non-null  float64
#  9    mamh_tt    98963 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 7.6+ MB

# %%
sinhvien_diem = pd.merge(df_sinhvien, df_diem, on='mssv', how='outer')
print(sinhvien_diem)
# Out:
#            id_x                                      mssv   namsinh  \
# 0           1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0
# 1           1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0
# 2           1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0
# 3           1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0
# 4           1.0  BE375BAAXPvAibaEXe9JDlHA4z2GHJ3/PVStCxR2    1995.0
# ...         ...                                       ...       ...
# 106059  19283.0  7D7633B0XPvAibaEXe95IhrkYSGfcCQVGm4nFGyt    2000.0
# 106060  19284.0  AB431338XPvAibaEXe8xMCTZ03/BexWzDCyWVsT3    2001.0
# 106061  19285.0  75AD7B4AXPvAibaEXe8xMCTZ03/BewoGrWSt0ZXM    2001.0
# 106062  19345.0  CB263C18XPvAibaEXe8xMCTZ03/Be8yk40QWdPiR    2000.0
# 106063  21059.0  7CD9B404XPvAibaEXe8M4ltS8XjC9c/g97NvpP52    2001.0
#
#          gioitinh                   noisinh        lopsh     khoa   hedt  \
# 0             1.0           TP. Hồ Chí Minh     KTPM0001     CNPM   CQUI
# ...
