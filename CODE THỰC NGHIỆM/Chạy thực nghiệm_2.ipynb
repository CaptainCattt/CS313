# %% [markdown]
# #Import lib

# %%
import sklearn.externals as extjoblib
import joblib
import time

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
import numpy as np
from sklearn.linear_model import SGDRegressor

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 8.4 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# #Load dữ liệu chia train test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Khai thác dữ liệu và ứng dụng - CS313.N21/CHẠY THỰC NGHIỆM/data_v5.csv')

# %%
df
# Out:
#       Unnamed: 0  gioitinh  namnhaphoc  hieusotuoi  dien_tt  loaitruong  \
# 0              0       1.0      2016.0         0.0        0           4
# 1              1       0.0      2016.0         0.0        0           1
# 2              2       1.0      2016.0         0.0        0           4
# 3              3       1.0      2016.0         0.0        0           1
# 4              4       1.0      2016.0         0.0        0           1
# ...          ...       ...         ...         ...      ...         ...
# 8039        8039       1.0      2013.0         0.0        0           1
# 8040        8040       1.0      2013.0         0.0        0           2
# 8041        8041       0.0      2019.0         0.0        0           1
# 8042        8042       1.0      2019.0         0.0        0           1
# 8043        8043       1.0      2016.0         0.0        0           1
#
#       khuvuc  xeploai_diemtt  avxl  xeploai_hk1  ...  xeploai_hk3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8044 entries, 0 to 8043
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      8044 non-null   int64
#  1   gioitinh        8044 non-null   float64
#  2   namnhaphoc      8044 non-null   float64
#  3   hieusotuoi      8044 non-null   float64
#  4   dien_tt         8044 non-null   int64
#  5   loaitruong      8044 non-null   int64
#  6   khuvuc          8044 non-null   int64
#  7   xeploai_diemtt  8044 non-null   int64
#  8   avxl            8044 non-null   int64
#  9   xeploai_hk1     8044 non-null   int64
#  10  xeploai_hk2     8044 non-null   int64
#  11  xeploai_hk3     8044 non-null   int64
#  12  xeploai_hk4     8044 non-null   int64
#  13  xeploai_hk5     8044 non-null   int64
#  14  xeploai_hk6     8044 non-null   int64
#  15  xeploai_hk7     8044 non-null   int64
#  16  xeploai_hk8     8044 non-null   int64
# ...

# %%
data =df

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

#

# Chọn các thuộc tính đầu vào (features) và thuộc tính đầu ra (target)
features1 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl']
target1 = 'xeploai_hk1'

features2 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1']
target2 = 'xeploai_hk2'

features3 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2']
target3 = 'xeploai_hk3'

features4 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2','xeploai_hk3']
target4 = 'xeploai_hk4'

features5 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2','xeploai_hk3','xeploai_hk4']
target5 = 'xeploai_hk5'

features6 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2','xeploai_hk3','xeploai_hk4','xeploai_hk5']
target6 = 'xeploai_hk6'

features7 = [ 'gioitinh', 'hieusotuoi',  'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2','xeploai_hk3','xeploai_hk4','xeploai_hk5','xeploai_hk6']
target7 = 'xeploai_hk7'

features8 = [ 'gioitinh', 'hieusotuoi', 'dien_tt', 'loaitruong', 'khuvuc', 'avxl','xeploai_hk1','xeploai_hk2','xeploai_hk3','xeploai_hk4','xeploai_hk5',
             'xeploai_hk6','xeploai_hk7']
target8 = 'xeploai_hk8'

# Kiểm tra và xử lý giá trị thiếu trong X và y nếu có

X1 = data[features1]
y1 = data[target1]

X2 = data[features2]
y2 = data[target2]

X3 = data[features3]
y3 = data[target3]

X4 = data[features4]
y4 = data[target4]


X5 = data[features5]
y5 = data[target5]


X6 = data[features6]
y6 = data[target6]

X7 = data[features7]
y7 = data[target7]

X8 = data[features8]
y8 = data[target8]




# 3. Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=42)

X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.2, random_state=42)

X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.2, random_state=42)

X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=0.2, random_state=42)

X_train6, X_test6, y_train6, y_test6 = train_test_split(X6, y6, test_size=0.2, random_state=42)

X_train7, X_test7, y_train7, y_test7 = train_test_split(X7, y7, test_size=0.2, random_state=42)

X_train8, X_test8, y_train8, y_test8 = train_test_split(X8, y8, test_size=0.2, random_state=42)

# %% [markdown]
# #Chạy thực nghiệm

# %% [markdown]
# ##CatBoostClassifier

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train1.value_counts()
percentages= 100 * counts / len(y_train1)

# %%
percentages
# Out:
# 2    41.398601
# 3    24.926185
# 1    23.123543
# 0     6.216006
# 4     4.335664
# Name: xeploai_hk1, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train2.value_counts()
percentages2= 100 * counts / len(y_train1)

# %%
percentages2
# Out:
# 2    36.410256
# 3    25.641026
# 1    16.596737
# 4    13.379953
# 0     7.972028
# Name: xeploai_hk2, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train3.value_counts()
percentages3= 100 * counts / len(y_train1)

# %%
percentages3
# Out:
# 2    45.361305
# 3    21.600622
# 1    18.026418
# 0    10.567211
# 4     4.444444
# Name: xeploai_hk3, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train4.value_counts()
percentages4= 100 * counts / len(y_train1)

# %%
percentages4
# Out:
# 2    43.061383
# 1    22.657343
# 3    16.845377
# 0    10.489510
# 4     6.946387
# Name: xeploai_hk4, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train5.value_counts()
percentages5= 100 * counts / len(y_train1)

# %%
percentages5
# Out:
# 2    41.087801
# 1    23.993784
# 3    16.083916
# 0    14.296814
# 4     4.537685
# Name: xeploai_hk5, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train6.value_counts()
percentages6= 100 * counts / len(y_train1)

# %%
percentages6
# Out:
# 2    38.989899
# 1    27.909868
# 0    13.908314
# 3    12.820513
# 4     6.371406
# Name: xeploai_hk6, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train7.value_counts()
percentages7= 100 * counts / len(y_train1)

# %%
percentages7
# Out:
# 0    37.871018
# 2    27.956488
# 1    21.041181
# 3     9.743590
# 4     3.387723
# Name: xeploai_hk7, dtype: float64

# %% [markdown]
# ### tính trọng số

# %%
counts = y_train8.value_counts()
percentages8= 100 * counts / len(y_train1)

# %%
percentages8
# Out:
# 0    37.684538
# 2    22.828283
# 1    22.688423
# 3     8.842269
# 4     7.956488
# Name: xeploai_hk8, dtype: float64

# %% [markdown]
# ###Chạy model

# %%
iterations = 1500
learning_rate = 0.02
depth = 6
l2_leaf_reg = 0.9
class_weight= {0:percentages[0], 1: percentages[1],2:percentages[2], 3:percentages[3], 4:percentages[4] }

# %%
model1 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights=class_weight,
                                  random_seed=0)
model1.fit(X_train1, y_train1)
model2 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights=percentages2,
                                  random_seed=0)
model2.fit(X_train2, y_train2)
model3 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights=percentages3,
                                  random_seed=0)
model3.fit(X_train3, y_train3)
model4 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights = percentages4,
                                  random_seed=0)
model4.fit(X_train4, y_train4)
model5 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights=percentages5,
                                  random_seed=0)
model5.fit(X_train5, y_train5)
model6 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                   class_weights=percentages6,
                                  random_seed=0)
model6.fit(X_train6, y_train6)
model7 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights=percentages7,
                                  random_seed=0)
model7.fit(X_train7, y_train7)
model8 = CatBoostClassifier(iterations = iterations, 
                                  learning_rate=learning_rate,
                                  depth = depth, 
                                  l2_leaf_reg=l2_leaf_reg,
                                  class_weights= percentages8,
                                  random_seed=0)
model8.fit(X_train8, y_train8)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1000:	learn: 0.7086625	total: 6.2s	remaining: 3.09s
# 1001:	learn: 0.7085237	total: 6.21s	remaining: 3.09s
# 1002:	learn: 0.7084312	total: 6.22s	remaining: 3.08s
# 1003:	learn: 0.7082883	total: 6.23s	remaining: 3.08s
# 1004:	learn: 0.7081973	total: 6.24s	remaining: 3.07s
# 1005:	learn: 0.7080899	total: 6.25s	remaining: 3.07s
# 1006:	learn: 0.7079495	total: 6.27s	remaining: 3.07s
# 1007:	learn: 0.7078219	total: 6.28s	remaining: 3.06s
# 1008:	learn: 0.7076518	total: 6.29s	remaining: 3.06s
# 1009:	learn: 0.7074998	total: 6.31s	remaining: 3.06s
# 1010:	learn: 0.7073558	total: 6.32s	remaining: 3.06s
# 1011:	learn: 0.7072556	total: 6.33s	remaining: 3.05s
# 1012:	learn: 0.7071252	total: 6.34s	remaining: 3.05s
# 1013:	learn: 0.7069640	total: 6.35s	remaining: 3.04s
# 1014:	learn: 0.7068591	total: 6.36s	remaining: 3.04s
# 1015:	learn: 0.7067636	total: 6.38s	remaining: 3.04s
# 1016:	learn: 0.7066580	total: 6.38s	remaining: 3.03s
# ...

# %%
# 5. Đánh giá mô hình
y_pred1 = model1.predict(X_test1)
accuracy1 = accuracy_score(y_test1, y_pred1)
print("Độ chính xác1:", accuracy1)

# 5. Đánh giá mô hình
y_pred2 = model2.predict(X_test2)
accuracy2 = accuracy_score(y_test2, y_pred2)
print("Độ chính xác2:", accuracy2)

#5. Đánh giá mô hình
y_pred3 = model3.predict(X_test3)
accuracy3 = accuracy_score(y_test3, y_pred3)
print("Độ chính xác3:", accuracy3)


# 5. Đánh giá mô hình
y_pred4 = model4.predict(X_test4)
accuracy4 = accuracy_score(y_test4, y_pred4)
print("Độ chính xác4:", accuracy4)


# 5. Đánh giá mô hình
y_pred5 = model5.predict(X_test5)
accuracy5 = accuracy_score(y_test5, y_pred5)
print("Độ chính xác5:", accuracy5)


# 5. Đánh giá mô hình
y_pred6 = model6.predict(X_test6)
accuracy6 = accuracy_score(y_test6, y_pred6)
print("Độ chính xác6:", accuracy6)


# 5. Đánh giá mô hình
y_pred7 = model7.predict(X_test7)
accuracy7 = accuracy_score(y_test7, y_pred7)
print("Độ chính xác7:", accuracy7)

# 5. Đánh giá mô hình
y_pred8 = model8.predict(X_test8)
accuracy8 = accuracy_score(y_test8, y_pred8)
print("Độ chính xác8:", accuracy8)
# Out:
# Độ chính xác1: 0.39341205717837163
# Độ chính xác2: 0.4630205096333126
# Độ chính xác3: 0.531385954008701
# Độ chính xác4: 0.6171535114978247
# Độ chính xác5: 0.5947793660658794
# Độ chính xác6: 0.5978868862647607
# Độ chính xác7: 0.5699192044748291
# Độ chính xác8: 0.6873834679925419

# %% [markdown]
# ##con

# %%
print('\n clasification report:\n', classification_report(y_test1, y_pred1))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       103
#            1       0.34      0.06      0.10       377
#            2       0.40      0.94      0.56       636
#            3       0.35      0.03      0.05       405
#            4       0.00      0.00      0.00        88
#
#     accuracy                           0.39      1609
#    macro avg       0.22      0.21      0.14      1609
# weighted avg       0.33      0.39      0.26      1609
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print('\n clasification report:\n', classification_report(y_test2, y_pred2))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.16      0.39      0.23       126
#            1       0.54      0.66      0.60       267
#            2       0.54      0.60      0.57       592
#            3       0.41      0.27      0.32       372
#            4       0.72      0.27      0.39       252
#
#     accuracy                           0.46      1609
#    macro avg       0.48      0.44      0.42      1609
# weighted avg       0.51      0.46      0.46      1609

# %%
print('\n clasification report:\n', classification_report(y_test3, y_pred3))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.34      0.71      0.46       173
#            1       0.61      0.56      0.58       301
#            2       0.59      0.75      0.66       706
#            3       0.46      0.10      0.16       344
#            4       0.00      0.00      0.00        85
#
#     accuracy                           0.53      1609
#    macro avg       0.40      0.42      0.37      1609
# weighted avg       0.51      0.53      0.48      1609
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print('\n clasification report:\n', classification_report(y_test4, y_pred4))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.75      0.61       163
#            1       0.66      0.66      0.66       372
#            2       0.66      0.75      0.70       728
#            3       0.34      0.17      0.23       225
#            4       0.68      0.36      0.47       121
#
#     accuracy                           0.62      1609
#    macro avg       0.57      0.54      0.53      1609
# weighted avg       0.60      0.62      0.60      1609

# %%
print('\n clasification report:\n', classification_report(y_test5, y_pred5))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.79      0.65       230
#            1       0.64      0.70      0.67       388
#            2       0.60      0.72      0.65       653
#            3       0.45      0.13      0.20       265
#            4       0.00      0.00      0.00        73
#
#     accuracy                           0.59      1609
#    macro avg       0.45      0.47      0.44      1609
# weighted avg       0.55      0.59      0.55      1609
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print('\n clasification report:\n', classification_report(y_test6, y_pred6))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.86      0.72       212
#            1       0.57      0.81      0.66       422
#            2       0.65      0.57      0.61       662
#            3       0.31      0.11      0.17       204
#            4       0.66      0.34      0.45       109
#
#     accuracy                           0.60      1609
#    macro avg       0.56      0.54      0.52      1609
# weighted avg       0.58      0.60      0.57      1609

# %%
print('\n clasification report:\n', classification_report(y_test7, y_pred7))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.82      0.69       602
#            1       0.58      0.41      0.48       372
#            2       0.52      0.59      0.56       446
#            3       0.46      0.04      0.08       134
#            4       0.00      0.00      0.00        55
#
#     accuracy                           0.57      1609
#    macro avg       0.43      0.37      0.36      1609
# weighted avg       0.54      0.57      0.53      1609
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print('\n clasification report:\n', classification_report(y_test8, y_pred8))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       610
#            1       0.63      0.70      0.66       375
#            2       0.47      0.64      0.54       357
#            3       0.35      0.05      0.09       147
#            4       0.68      0.28      0.40       120
#
#     accuracy                           0.69      1609
#    macro avg       0.61      0.52      0.52      1609
# weighted avg       0.68      0.69      0.66      1609

# %% [markdown]
# ## LGBM model

# %%
iterations = 1500
learning_rate = 0.2
depth = 6
l2_leaf_reg = 3

# %%
model_1 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_1.fit(X_train1, y_train1,verbose = 100)
model_2 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_2.fit(X_train2, y_train2,verbose = 100)
model_3 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_3.fit(X_train3, y_train3,verbose = 100)
model_4 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_4.fit(X_train4, y_train4,verbose = 100)
model_5 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_5.fit(X_train5, y_train5,verbose = 100)
model_6 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_6.fit(X_train6, y_train6,verbose = 100)
model_7 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_7.fit(X_train7, y_train7,verbose = 100)
model_8 = LGBMClassifier(objective = 'multiclass',
                       random_state = 42,
                       boosting_type= 'gbdt',
                      class_weight = 'balanced',
                      learning_rate = 0.2,
                      max_depth = 18,
                      min_split_gain= 0.1,
                      n_estimators= 200,
                      num_leaves= 24,
                      reg_alpha= 0.05,
                      reg_lambda= 1,
                      subsample= 1)
model_8.fit(X_train8, y_train8,verbose = 100)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.10/dist-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.10/dist-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# ...

# %%
# 5. Đánh giá mô hình
y_pred1 = model_1.predict(X_test1)
accuracy1 = accuracy_score(y_test1, y_pred1)
print("Độ chính xác1:", accuracy1)

y_pred2 = model_2.predict(X_test2)
accuracy2 = accuracy_score(y_test2, y_pred2)
print("Độ chính xác2:", accuracy2)

#5. Đánh giá mô hình
y_pred3 = model_3.predict(X_test3)
accuracy3 = accuracy_score(y_test3, y_pred3)
print("Độ chính xác3:", accuracy3)


# 5. Đánh giá mô hình
y_pred4 = model_4.predict(X_test4)
accuracy4 = accuracy_score(y_test4, y_pred4)
print("Độ chính xác4:", accuracy4)


# 5. Đánh giá mô hình
y_pred5 = model_5.predict(X_test5)
accuracy5 = accuracy_score(y_test5, y_pred5)
print("Độ chính xác5:", accuracy5)


# 5. Đánh giá mô hình
y_pred6 = model_6.predict(X_test6)
accuracy6 = accuracy_score(y_test6, y_pred6)
print("Độ chính xác6:", accuracy6)


# 5. Đánh giá mô hình
y_pred7 = model_7.predict(X_test7)
accuracy7 = accuracy_score(y_test7, y_pred7)
print("Độ chính xác7:", accuracy7)

# 5. Đánh giá mô hình
y_pred8 = model_8.predict(X_test8)
accuracy8 = accuracy_score(y_test8, y_pred8)
print("Độ chính xác8:", accuracy8)
# Out:
# Độ chính xác1: 0.22684897451833436
# Độ chính xác2: 0.4406463642013673
# Độ chính xác3: 0.48042262274704783
# Độ chính xác4: 0.5910503418272218
# Độ chính xác5: 0.5674331883157241
# Độ chính xác6: 0.5779987569919205
# Độ chính xác7: 0.531385954008701
# Độ chính xác8: 0.6606587942821628

# %% [markdown]
# ##con

# %%
print('\n clasification report:\n', classification_report(y_test1, y_pred1))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.10      0.41      0.15       103
#            1       0.35      0.56      0.43       377
#            2       0.40      0.06      0.10       636
#            3       0.31      0.13      0.18       405
#            4       0.08      0.26      0.12        88
#
#     accuracy                           0.23      1609
#    macro avg       0.25      0.28      0.20      1609
# weighted avg       0.33      0.23      0.20      1609

# %%
print('\n clasification report:\n', classification_report(y_test2, y_pred2))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.15      0.42      0.22       126
#            1       0.50      0.72      0.59       267
#            2       0.56      0.48      0.52       592
#            3       0.38      0.15      0.22       372
#            4       0.58      0.48      0.53       252
#
#     accuracy                           0.44      1609
#    macro avg       0.43      0.45      0.41      1609
# weighted avg       0.48      0.44      0.44      1609

# %%
print('\n clasification report:\n', classification_report(y_test3, y_pred3))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.34      0.37       173
#            1       0.53      0.69      0.60       301
#            2       0.66      0.42      0.51       706
#            3       0.40      0.49      0.45       344
#            4       0.20      0.52      0.29        85
#
#     accuracy                           0.48      1609
#    macro avg       0.44      0.49      0.44      1609
# weighted avg       0.53      0.48      0.49      1609

# %%
print('\n clasification report:\n', classification_report(y_test4, y_pred4))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.66      0.64       163
#            1       0.65      0.77      0.71       372
#            2       0.73      0.53      0.61       728
#            3       0.32      0.48      0.38       225
#            4       0.50      0.53      0.52       121
#
#     accuracy                           0.59      1609
#    macro avg       0.57      0.59      0.57      1609
# weighted avg       0.63      0.59      0.60      1609

# %%
print('\n clasification report:\n', classification_report(y_test5, y_pred5))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.56      0.63       230
#            1       0.62      0.74      0.68       388
#            2       0.66      0.54      0.59       653
#            3       0.39      0.39      0.39       265
#            4       0.24      0.53      0.33        73
#
#     accuracy                           0.57      1609
#    macro avg       0.53      0.55      0.52      1609
# weighted avg       0.59      0.57      0.57      1609

# %%
print('\n clasification report:\n', classification_report(y_test6, y_pred6))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       212
#            1       0.60      0.76      0.67       422
#            2       0.66      0.44      0.53       662
#            3       0.30      0.42      0.35       204
#            4       0.49      0.60      0.54       109
#
#     accuracy                           0.58      1609
#    macro avg       0.57      0.60      0.57      1609
# weighted avg       0.60      0.58      0.58      1609

# %%
print('\n clasification report:\n', classification_report(y_test7, y_pred7))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.54      0.64       602
#            1       0.53      0.57      0.55       372
#            2       0.55      0.51      0.53       446
#            3       0.26      0.46      0.33       134
#            4       0.22      0.60      0.32        55
#
#     accuracy                           0.53      1609
#    macro avg       0.47      0.53      0.47      1609
# weighted avg       0.60      0.53      0.55      1609

# %%
print('\n clasification report:\n', classification_report(y_test8, y_pred8))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       610
#            1       0.66      0.63      0.65       375
#            2       0.49      0.46      0.47       357
#            3       0.30      0.41      0.34       147
#            4       0.38      0.44      0.41       120
#
#     accuracy                           0.66      1609
#    macro avg       0.56      0.57      0.56      1609
# weighted avg       0.68      0.66      0.67      1609

# %% [markdown]
# ##SVM

# %%
# # Xác định các tiền đề và điểm của các học kỳ trước đó
# features = ['gioitinh',	'hieusotuoi','dien_tt'	,'loaitruong',	'khuvuc','xeploai_diemtt','avxl']
# params = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
#           'gamma':['scale', 'auto'],
#           'decision_function_shape':['ovo', 'ovr']}

# # Tạo một mô hình dự đoán xếp loại điểm cho mỗi học kỳ
# models = {}
# for i in range(1, 13):
#     # Tạo dữ liệu huấn luyện cho mô hình
#     features_prev = ['xeploai_hk{}'.format(j) for j in range(1, i)]
#     X_train = train_data[features + features_prev]
#     y_train = train_data['xeploai_hk{}'.format(i)]

#     # Tạo mô hình cho học kỳ i
#     if i == 1:
#         model_1 =SVC()
#         model = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
#         model.fit(X_train, y_train)
#     else:
#         model_1 = SVC()
#         model = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
#         model.fit(X_train, y_train)

#         # Cập nhật mô hình cho học kỳ i-1
#         X_train_prev = train_data[features + ['xeploai_hk{}'.format(j) for j in range(1, i)]]
#         y_train_prev = train_data['xeploai_hk{}'.format(i-1)]
#         models[i-1].fit(X_train_prev, y_train_prev)

#     # Lưu mô hình cho học kỳ i
#     models[i] = model
#     joblib.dump(model, 'my_model.pkl', compress=9)
#     # Đánh giá hiệu quả của mô hình dự đoán cho học kỳ i
#     features_prev = ['xeploai_hk{}'.format(j) for j in range(1, i)]
#     X_val = val_data[features + features_prev]
#     y_val = val_data['xeploai_hk{}'.format(i)]
#     y_pred = model.predict(X_val)
#     acc = accuracy_score(y_val, y_pred)
#     f1 = f1_score(y_val, y_pred, average = 'macro')
#     print('xeploai_hk{} - Accuracy: {:.2f} '.format(i, acc),'F1_score: {:.2f}'.format( f1))
#     #print('\n clasification report:\n', classification_report(y_val, y_pred))

# %% [markdown]
# ##GradientBoosting

# %%
# # Xác định các tiền đề và điểm của các học kỳ trước đó
# features = ['gioitinh',	'hieusotuoi','dien_tt'	,'loaitruong',	'khuvuc','xeploai_diemtt','avxl']
# params = {
#     'learning_rate': [0.01, 0.1, 1],
#     'max_depth': [3, 5, 7, 9],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4],
# }
# # Tạo một mô hình dự đoán xếp loại điểm cho mỗi học kỳ
# models = {}
# for i in range(1, 4):
#     # Tạo dữ liệu huấn luyện cho mô hình
#     features_prev = ['xeploai_hk{}'.format(j) for j in range(1, i)]
#     X_train = train_data[features + features_prev]
#     y_train = train_data['xeploai_hk{}'.format(i)]

#     # Tạo mô hình cho học kỳ i
#     if i == 1:
#         model_1 =GradientBoostingClassifier()
#         model = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
#         model.fit(X_train, y_train)
#     else:
#         model_1 = GradientBoostingClassifier()
#         model = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
#         model.fit(X_train, y_train)
#     # Lưu mô hình cho học kỳ i
#     models[i] = model
#     print("Best parameters: ", model.best_params_)
#     #joblib.dump(model, 'my_model.pkl', compress=9)
#     # Đánh giá hiệu quả của mô hình dự đoán cho học kỳ i
#     features_prev = ['xeploai_hk{}'.format(j) for j in range(1, i)]
#     X_val = val_data[features + features_prev]
#     y_val = val_data['xeploai_hk{}'.format(i)]
#     y_pred = model.predict(X_val)
#     acc = accuracy_score(y_val, y_pred)
#     f1 = f1_score(y_val, y_pred, average = 'macro')
#     print('xeploai_hk{} - Accuracy: {:.2f} '.format(i, acc),'F1_score: {:.2f}'.format( f1))
#     #print('\n clasification report:\n', classification_report(y_val, y_pred))
#     y_pred_2['xeploai_hk{}'.format(i)] =  y_pred

# %%
# 4. Xây dựng mô hình GradientBoosting.
params= {
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 7, 9],
}
model_1 =GradientBoostingClassifier()
model1 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model1.fit(X_train1, y_train1)

model2 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model2.fit(X_train2, y_train2)

model3 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model3.fit(X_train3, y_train3)

model4 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model4.fit(X_train4, y_train4)

model5 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model5.fit(X_train5, y_train5)

model6 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model6.fit(X_train6, y_train6)

model7 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model7.fit(X_train7, y_train7)

# model8 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
# model8.fit(X_train8, y_train8)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'max_depth': [3, 5, 7, 9]})

# %%
params= {
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 7, 9],
}
model8 = GridSearchCV(estimator= model_1, param_grid=params, cv=5)
model8.fit(X_train8, y_train8)
# Out:
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(class_weight='balanced',
#                                       learning_rate=0.2, max_depth=18,
#                                       min_split_gain=0.1, n_estimators=200,
#                                       num_leaves=24, objective='multiclass',
#                                       random_state=42, reg_alpha=0.05,
#                                       reg_lambda=1, subsample=1),
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'max_depth': [3, 5, 7, 9]})

# %%
best_rf =model8.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  model8.best_params_)
# Out:
# Best hyperparameters: {'learning_rate': 0.01, 'max_depth': 5}

# %%
# 5. Đánh giá mô hình
y_pred1 = model1.predict(X_test1)
accuracy1 = accuracy_score(y_test1, y_pred1)
print("Độ chính xác1:", accuracy1)

# 5. Đánh giá mô hình
y_pred2 = model2.predict(X_test2)
accuracy2 = accuracy_score(y_test2, y_pred2)
print("Độ chính xác2:", accuracy2)

#5. Đánh giá mô hình
y_pred3 = model3.predict(X_test3)
accuracy3 = accuracy_score(y_test3, y_pred3)
print("Độ chính xác3:", accuracy3)


# 5. Đánh giá mô hình
y_pred4 = model4.predict(X_test4)
accuracy4 = accuracy_score(y_test4, y_pred4)
print("Độ chính xác4:", accuracy4)


# 5. Đánh giá mô hình
y_pred5 = model5.predict(X_test5)
accuracy5 = accuracy_score(y_test5, y_pred5)
print("Độ chính xác5:", accuracy5)


# 5. Đánh giá mô hình
y_pred6 = model6.predict(X_test6)
accuracy6 = accuracy_score(y_test6, y_pred6)
print("Độ chính xác6:", accuracy6)


# 5. Đánh giá mô hình
y_pred7 = model7.predict(X_test7)
accuracy7 = accuracy_score(y_test7, y_pred7)
print("Độ chính xác7:", accuracy7)

# 5. Đánh giá mô hình
y_pred8 = model8.predict(X_test8)
accuracy8 = accuracy_score(y_test8, y_pred8)
print("Độ chính xác8:", accuracy8)
# Out:
# Độ chính xác1: 0.40087010565568676
# Độ chính xác2: 0.5214418893722809
# Độ chính xác3: 0.5630826600372902
# Độ chính xác4: 0.5674331883157241
# Độ chính xác5: 0.6096954630205096
# Độ chính xác6: 0.6339341205717837
# Độ chính xác7: 0.5786202610316967
# Độ chính xác8: 0.6998135487880671

# %% [markdown]
# ##con

# %%
print('\n clasification report:\n', classification_report(y_test1, y_pred1))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.02      0.04       103
#            1       0.45      0.12      0.19       377
#            2       0.40      0.93      0.56       636
#            3       0.36      0.01      0.02       405
#            4       1.00      0.01      0.02        88
#
#     accuracy                           0.40      1609
#    macro avg       0.57      0.22      0.17      1609
# weighted avg       0.45      0.40      0.27      1609

# %%
print('\n clasification report:\n', classification_report(y_test2, y_pred2))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.20      0.01      0.02       126
#            1       0.57      0.63      0.60       267
#            2       0.55      0.59      0.57       592
#            3       0.41      0.53      0.46       372
#            4       0.67      0.50      0.57       252
#
#     accuracy                           0.52      1609
#    macro avg       0.48      0.45      0.44      1609
# weighted avg       0.51      0.52      0.50      1609

# %%
print('\n clasification report:\n', classification_report(y_test3, y_pred3))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.61      0.51       173
#            1       0.67      0.46      0.54       301
#            2       0.60      0.77      0.68       706
#            3       0.45      0.33      0.38       344
#            4       0.67      0.05      0.09        85
#
#     accuracy                           0.56      1609
#    macro avg       0.57      0.44      0.44      1609
# weighted avg       0.57      0.56      0.54      1609

# %%
print('\n clasification report:\n', classification_report(y_test4, y_pred4))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44       163
#            1       0.69      0.52      0.59       372
#            2       0.61      0.80      0.69       728
#            3       0.32      0.19      0.24       225
#            4       0.34      0.09      0.14       121
#
#     accuracy                           0.57      1609
#    macro avg       0.47      0.42      0.42      1609
# weighted avg       0.55      0.57      0.54      1609

# %%
print('\n clasification report:\n', classification_report(y_test5, y_pred5))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.68      0.65       230
#            1       0.70      0.62      0.66       388
#            2       0.60      0.79      0.68       653
#            3       0.49      0.25      0.33       265
#            4       0.23      0.08      0.12        73
#
#     accuracy                           0.61      1609
#    macro avg       0.53      0.48      0.49      1609
# weighted avg       0.59      0.61      0.59      1609

# %%
print('\n clasification report:\n', classification_report(y_test6, y_pred6))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       212
#            1       0.66      0.66      0.66       422
#            2       0.62      0.74      0.67       662
#            3       0.32      0.14      0.20       204
#            4       0.63      0.48      0.54       109
#
#     accuracy                           0.63      1609
#    macro avg       0.60      0.57      0.57      1609
# weighted avg       0.61      0.63      0.62      1609

# %%
print('\n clasification report:\n', classification_report(y_test7, y_pred7))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       602
#            1       0.59      0.44      0.50       372
#            2       0.50      0.67      0.57       446
#            3       0.36      0.22      0.27       134
#            4       0.41      0.13      0.19        55
#
#     accuracy                           0.58      1609
#    macro avg       0.51      0.43      0.45      1609
# weighted avg       0.57      0.58      0.57      1609

# %%
print('\n clasification report:\n', classification_report(y_test8, y_pred8))
# Out:
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94       610
#            1       0.65      0.70      0.67       375
#            2       0.49      0.65      0.56       357
#            3       0.40      0.14      0.20       147
#            4       0.61      0.35      0.44       120
#
#     accuracy                           0.70      1609
#    macro avg       0.62      0.55      0.56      1609
# weighted avg       0.70      0.70      0.69      1609

# %% [markdown]
# #Học gia tăng

# %%
df
# Out:
#       Unnamed: 0  gioitinh  namnhaphoc  hieusotuoi  dien_tt  loaitruong  \
# 0              0       1.0      2016.0         0.0        0           4
# 1              1       0.0      2016.0         0.0        0           1
# 2              2       1.0      2016.0         0.0        0           4
# 3              3       1.0      2016.0         0.0        0           1
# 4              4       1.0      2016.0         0.0        0           1
# ...          ...       ...         ...         ...      ...         ...
# 8039        8039       1.0      2013.0         0.0        0           1
# 8040        8040       1.0      2013.0         0.0        0           2
# 8041        8041       0.0      2019.0         0.0        0           1
# 8042        8042       1.0      2019.0         0.0        0           1
# 8043        8043       1.0      2016.0         0.0        0           1
#
#       khuvuc  xeploai_diemtt  avxl  xeploai_hk1  ...  xeploai_hk3  \
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
start_time = time.time()

# Đọc dữ liệu từ file CSV

# Chia dữ liệu thành tập huấn luyện và kiểm tra
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Khởi tạo mô hình
model = SGDClassifier(loss='log', max_iter=1000, tol=1e-3, random_state=42)

# Huấn luyện mô hình
for i in range(1, 13):
    X_train = train_data.iloc[:, :-12]
    y_train = train_data.iloc[:, -12 + i - 1]
    X_test = test_data.iloc[:, :-12]
    y_test = test_data.iloc[:, -12 + i - 1]

    model.partial_fit(X_train, y_train, classes=[0,1,2,3,4,5,6,7])
    
    # Dự đoán và đánh giá mô hình
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f'Học kỳ {i}: Độ chính xác = {acc:.2f}')

end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Học kỳ 1: Độ chính xác = 0.32
# Học kỳ 2: Độ chính xác = 0.19
# Học kỳ 3: Độ chính xác = 0.30
# Học kỳ 4: Độ chính xác = 0.17
# Học kỳ 5: Độ chính xác = 0.41
# Học kỳ 6: Độ chính xác = 0.41
# Học kỳ 7: Độ chính xác = 0.08
# Học kỳ 8: Độ chính xác = 0.22
# Học kỳ 9: Độ chính xác = 0.89
# Học kỳ 10: Độ chính xác = 0.08
# Học kỳ 11: Độ chính xác = 0.41
# Học kỳ 12: Độ chính xác = 0.97
# Elapsed time: 0.14 seconds
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
